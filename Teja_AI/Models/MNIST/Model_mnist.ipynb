# %%
import tensorflow as tf
from tensorflow import keras

# %%
Demo_data = tf.keras.datasets.mnist

# %%
# Classifying the data
(X_train,y_train),(X_test,y_test) = Demo_data.load_data()

#Normalizing the data
X_train, X_test = X_train/255, X_test/255
# Out:
# ...
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
X_train.shape,X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
# model defining
model = tf.keras.models.Sequential()

# %%
# adding layers to the model
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compliling with default learining rate i.e 0.0001

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train,y_train,epochs=1,batch_size=64,validation_data=(X_test,y_test))
# Out:
# 938/938 [==============================] - 5s 4ms/step - loss: 0.3428 - accuracy: 0.9011 - val_loss: 0.1560 - val_accuracy: 0.9551

# %% [markdown]
# #Learning Rates:
# 0.001
# 0.01
# 0.05
# 0.02

# %%
# Plotting graph Training Loss vs Validation Loss

import matplotlib.pyplot as plt
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.legend()
plt.show()


# Plotting graph Training Accuracy vs Validation Accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Validation Accuracy')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
List_Lr=np.linspace(0.1,0.001,10)
for l_rate in List_Lr:
  print(l_rate)
  Optimizer=tf.keras.optimizers.Adam(learning_rate=l_rate)
  model.compile(optimizer=Optimizer,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
  history=model.fit(X_train,y_train,epochs=10,batch_size=64,validation_data=(X_test,y_test))
  plt.plot(history.history['loss'],label='Training Loss')
  # plt.plot(history.history['Epochs'],label='Epochs')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()
  plt.plot(history.history['accuracy'], label='Training Accuracy')
  plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.title('Training Accuracy vs. Validation Accuracy')
  plt.legend()
  plt.show()
# Out:
# 0.1
# Epoch 1/10
# 938/938 [==============================] - 4s 4ms/step - loss: 1.1441 - accuracy: 0.7207 - val_loss: 0.8192 - val_accuracy: 0.7804
# Epoch 2/10
# 938/938 [==============================] - 3s 3ms/step - loss: 1.2527 - accuracy: 0.6150 - val_loss: 1.3890 - val_accuracy: 0.6276
# Epoch 3/10
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4442 - accuracy: 0.5344 - val_loss: 1.5693 - val_accuracy: 0.6203
# Epoch 4/10
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4154 - accuracy: 0.5408 - val_loss: 1.0869 - val_accuracy: 0.6742
# Epoch 5/10
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4769 - accuracy: 0.5021 - val_loss: 1.3749 - val_accuracy: 0.5043
# Epoch 6/10
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4884 - accuracy: 0.5117 - val_loss: 1.2802 - val_accuracy: 0.6052
# Epoch 7/10
# ...

# %%
Optimizer_1=tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=Optimizer_1,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train,y_train,epochs=100,batch_size=64,validation_data=(X_test,y_test))
plt.plot(history.history['loss'],label='Training Loss')
# plt.plot(history.history['Epochs'],label='Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Validation Accuracy')
plt.legend()
plt.show()



Optimizer_2=tf.keras.optimizers.Adam(learning_rate=0.02)
model.compile(optimizer=Optimizer_2,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train,y_train,epochs=100,batch_size=64,validation_data=(X_test,y_test))
plt.plot(history.history['loss'],label='Training Loss')
# plt.plot(history.history['Epochs'],label='Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 938/938 [==============================] - 4s 4ms/step - loss: 0.4124 - accuracy: 0.8412 - val_loss: 5.8025 - val_accuracy: 0.8490
# Epoch 2/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4055 - accuracy: 0.8434 - val_loss: 5.9500 - val_accuracy: 0.8531
# Epoch 3/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3958 - accuracy: 0.8435 - val_loss: 6.0913 - val_accuracy: 0.8545
# Epoch 4/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3931 - accuracy: 0.8437 - val_loss: 6.1576 - val_accuracy: 0.8538
# Epoch 5/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3978 - accuracy: 0.8436 - val_loss: 6.1681 - val_accuracy: 0.8535
# Epoch 6/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3949 - accuracy: 0.8442 - val_loss: 6.2552 - val_accuracy: 0.8537
# Epoch 7/100
# ...

# %%
Optimizer_3=tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=Optimizer_3,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train,y_train,epochs=100,batch_size=64,validation_data=(X_test,y_test))
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4780 - accuracy: 0.8265 - val_loss: 5.7288 - val_accuracy: 0.8436
# Epoch 2/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4779 - accuracy: 0.8267 - val_loss: 5.4391 - val_accuracy: 0.8463
# Epoch 3/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4818 - accuracy: 0.8274 - val_loss: 5.3137 - val_accuracy: 0.8437
# Epoch 4/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4814 - accuracy: 0.8278 - val_loss: 5.2979 - val_accuracy: 0.8456
# Epoch 5/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4668 - accuracy: 0.8278 - val_loss: 5.3268 - val_accuracy: 0.8481
# Epoch 6/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4679 - accuracy: 0.8266 - val_loss: 5.2842 - val_accuracy: 0.8434
# Epoch 7/100
# ...

# %%
Optimizer_4=tf.keras.optimizers.Adam(learning_rate=0.05)
model.compile(optimizer=Optimizer_4,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train,y_train,epochs=50,batch_size=64,validation_data=(X_test,y_test))
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
# plt.plot(history.history['Epochs'],label='Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 938/938 [==============================] - 4s 4ms/step - loss: 0.5984 - accuracy: 0.8266 - val_loss: 3.9945 - val_accuracy: 0.8316
# Epoch 2/50
# 938/938 [==============================] - 3s 3ms/step - loss: 0.7097 - accuracy: 0.8011 - val_loss: 3.3533 - val_accuracy: 0.8247
# Epoch 3/50
# 938/938 [==============================] - 3s 3ms/step - loss: 0.7138 - accuracy: 0.7876 - val_loss: 3.4449 - val_accuracy: 0.8165
# Epoch 4/50
# 938/938 [==============================] - 3s 3ms/step - loss: 0.7897 - accuracy: 0.7925 - val_loss: 3.7173 - val_accuracy: 0.8128
# Epoch 5/50
# 938/938 [==============================] - 3s 3ms/step - loss: 0.7255 - accuracy: 0.7832 - val_loss: 3.7405 - val_accuracy: 0.8182
# Epoch 6/50
# 938/938 [==============================] - 3s 3ms/step - loss: 0.7027 - accuracy: 0.7807 - val_loss: 3.4199 - val_accuracy: 0.8147
# Epoch 7/50
# ...

# %%
Optimizer_5=tf.keras.optimizers.Adam(learning_rate=0.02)
model.compile(optimizer=Optimizer_5,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train,y_train,epochs=20,batch_size=64,validation_data=(X_test,y_test))
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
# plt.plot(history.history['Epochs'],label='Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.4666 - accuracy: 0.8809 - val_loss: 1.4871 - val_accuracy: 0.9130
# Epoch 2/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4183 - accuracy: 0.8887 - val_loss: 1.2641 - val_accuracy: 0.9221
# Epoch 3/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3941 - accuracy: 0.8927 - val_loss: 1.3938 - val_accuracy: 0.9262
# Epoch 4/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3874 - accuracy: 0.8979 - val_loss: 1.4542 - val_accuracy: 0.9257
# Epoch 5/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3665 - accuracy: 0.9017 - val_loss: 1.6560 - val_accuracy: 0.9327
# Epoch 6/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3572 - accuracy: 0.9025 - val_loss: 1.3744 - val_accuracy: 0.9289
# Epoch 7/20
# ...

# %%
Optimizer_5=tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=Optimizer_5,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train,y_train,epochs=100,batch_size=64,validation_data=(X_test,y_test))
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
# plt.plot(history.history['Epochs'],label='Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs. Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4464 - accuracy: 0.8388 - val_loss: 5.9156 - val_accuracy: 0.8518
# Epoch 2/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4491 - accuracy: 0.8395 - val_loss: 6.0749 - val_accuracy: 0.8510
# Epoch 3/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4218 - accuracy: 0.8412 - val_loss: 6.1513 - val_accuracy: 0.8513
# Epoch 4/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4478 - accuracy: 0.8414 - val_loss: 5.7913 - val_accuracy: 0.8544
# Epoch 5/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4419 - accuracy: 0.8405 - val_loss: 6.0703 - val_accuracy: 0.8561
# Epoch 6/100
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4204 - accuracy: 0.8420 - val_loss: 6.0780 - val_accuracy: 0.8577
# Epoch 7/100
# ...
